# %%
# %pip install matplotlib
# %pip install --upgrade pennylane-qiskit
# %pip install qbraid
# Out:
# Requirement already satisfied: matplotlib in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/py39/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/py39/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1
# [notice] To update, run: /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pennylane-qiskit in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (0.41.0)
# Requirement already satisfied: qiskit<1.3,>=0.32 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (1.2.4)
# Requirement already satisfied: qiskit-aer<0.16.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (0.16.0)
# Requirement already satisfied: qiskit-ibm-runtime<=0.29 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (0.29.0)
# Requirement already satisfied: qiskit-ibm-provider in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (0.11.0)
# Requirement already satisfied: pennylane>=0.38 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (0.38.0)
# Requirement already satisfied: numpy in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (1.25.2)
# Requirement already satisfied: sympy<1.13 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (1.12.1)
# Requirement already satisfied: networkx>=2.2 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane-qiskit) (3.2.1)
# Requirement already satisfied: scipy in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (1.9.3)
# Requirement already satisfied: rustworkx>=0.14.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (0.16.0)
# Requirement already satisfied: autograd in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (1.6.2)
# Requirement already satisfied: toml in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (0.10.2)
# Requirement already satisfied: appdirs in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (0.7.1)
# Requirement already satisfied: cachetools in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (5.3.2)
# Requirement already satisfied: pennylane-lightning>=0.38 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (0.38.0)
# Requirement already satisfied: requests in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (2.31.0)
# Requirement already satisfied: typing-extensions in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (4.13.2)
# Requirement already satisfied: packaging in /opt/conda/envs/py39/lib/python3.9/site-packages (from pennylane>=0.38->pennylane-qiskit) (25.0)
# Requirement already satisfied: dill>=0.3 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit<1.3,>=0.32->pennylane-qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit<1.3,>=0.32->pennylane-qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit<1.3,>=0.32->pennylane-qiskit) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit<1.3,>=0.32->pennylane-qiskit) (0.13.0)
# Requirement already satisfied: psutil>=5 in /opt/conda/envs/py39/lib/python3.9/site-packages (from qiskit-aer<0.16.1->pennylane-qiskit) (7.0.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit-ibm-runtime<=0.29->pennylane-qiskit) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit-ibm-runtime<=0.29->pennylane-qiskit) (2.4.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /opt/conda/envs/py39/lib/python3.9/site-packages (from qiskit-ibm-runtime<=0.29->pennylane-qiskit) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit-ibm-runtime<=0.29->pennylane-qiskit) (0.63.0)
# Requirement already satisfied: pydantic>=2.5.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit-ibm-runtime<=0.29->pennylane-qiskit) (2.9.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from sympy<1.13->pennylane-qiskit) (1.3.0)
# Requirement already satisfied: websockets>=10.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qiskit-ibm-provider->pennylane-qiskit) (15.0.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.22.1 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/py39/lib/python3.9/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (2.23.4)
# Requirement already satisfied: six>=1.5 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit<1.3,>=0.32->pennylane-qiskit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->pennylane>=0.38->pennylane-qiskit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->pennylane>=0.38->pennylane-qiskit) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->pennylane>=0.38->pennylane-qiskit) (2023.11.17)
# Requirement already satisfied: cryptography>=1.3 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (44.0.2)
# Requirement already satisfied: pyspnego>=0.4.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (0.11.2)
# Requirement already satisfied: pbr>=2.0.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit<1.3,>=0.32->pennylane-qiskit) (6.1.1)
# Requirement already satisfied: future>=0.15.2 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from autograd->pennylane>=0.38->pennylane-qiskit) (0.18.3)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/envs/py39/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.22.1->ibm-platform-services>=0.22.6->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (2.10.1)
# Requirement already satisfied: setuptools in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit<1.3,>=0.32->pennylane-qiskit) (58.1.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/py39/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime<=0.29->pennylane-qiskit) (2.22)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1
# [notice] To update, run: /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qbraid in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (0.8.10)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid) (0.16.0)
# Requirement already satisfied: numpy>=1.17 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid) (1.25.2)
# Requirement already satisfied: openqasm3>=0.4.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from openqasm3[parser]>=0.4.0->qbraid) (0.4.0)
# Requirement already satisfied: qbraid-core>=0.1.29 in /opt/conda/envs/py39/lib/python3.9/site-packages (from qbraid) (0.1.36)
# Requirement already satisfied: pydantic>2.0.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid) (4.13.2)
# Requirement already satisfied: antlr4-python3-runtime<4.12,>=4.7 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from openqasm3[parser]>=0.4.0->qbraid) (4.9.2)
# Requirement already satisfied: importlib-metadata in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from openqasm3[parser]>=0.4.0->qbraid) (7.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/py39/lib/python3.9/site-packages (from pydantic>2.0.0->qbraid) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from pydantic>2.0.0->qbraid) (2.23.4)
# Requirement already satisfied: requests in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid-core>=0.1.29->qbraid) (2.31.0)
# Requirement already satisfied: urllib3 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from qbraid-core>=0.1.29->qbraid) (2.4.0)
# Requirement already satisfied: packaging in /opt/conda/envs/py39/lib/python3.9/site-packages (from qbraid-core>=0.1.29->qbraid) (25.0)
# Requirement already satisfied: zipp>=0.5 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from importlib-metadata->openqasm3[parser]>=0.4.0->qbraid) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->qbraid-core>=0.1.29->qbraid) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->qbraid-core>=0.1.29->qbraid) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages (from requests->qbraid-core>=0.1.29->qbraid) (2023.11.17)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1
# [notice] To update, run: /home/jovyan/.qbraid/environments/pennylane_l1hffv/pyenv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pennylane as qml
from qiskit_ibm_provider import IBMProvider
from pennylane.qnn import TorchLayer
import torch, torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np, random, math, time, functools
import pandas as pd
# Out:
# /tmp/ipykernel_7152/226192081.py:2: DeprecationWarning: The package qiskit_ibm_provider is being deprecated. Please see https://docs.quantum.ibm.com/api/migration-guides/qiskit-runtime to get instructions on how to migrate to qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   from qiskit_ibm_provider import IBMProvider

# %%
EMBED_MODE   = "amplitude"
provider = IBMProvider()
backend = provider.get_backend('ibm_brisbane')
n_inputs, n_hidden = 3, 4
n_qubits     = n_inputs + n_hidden
state_dim    = 2 ** n_qubits

n_layers_rec = 2
n_layers_out = 3
batch_size   = 32
seq_len      = 12
lr, epochs   = 0.005, 200
plot_every   = 20
SEED         = 42

# %%
torch.manual_seed(SEED); np.random.seed(SEED); random.seed(SEED)

# %%
dev_rec = qml.device("qiskit.remote", wires=n_inputs, backend=backend, shots=1024)
dev_out = qml.device("qiskit.remote", wires=n_hidden,  backend=backend, shots=1024)

# %%
def single_qubit_state(theta):
    return torch.stack([torch.cos(theta/2), torch.sin(theta/2)])

def kron_n(states):
    return functools.reduce(torch.kron, states)

def encode_to_amplitude(flow, temp, conc):
    theta = torch.tensor([ flow        * math.pi/10,   # 0–10  ➜  0–π
                           (temp-20)  * math.pi/20,    # 20–40 ➜  0–π
                           (conc-30)  * math.pi/20 ])  # 30–40 ➜  0–π
    data_q   = [single_qubit_state(th) for th in theta]
    hidden_q = [torch.tensor([1.,0.])] * n_hidden      # |0⟩ ancillas
    vec = kron_n(data_q + hidden_q)
    return vec / vec.norm()                            # length-128, unit-norm

# %%
@qml.qnode(dev_rec, interface="torch")
def qrnn_cell(inputs, weights):
    qml.AmplitudeEmbedding(inputs, wires=range(n_qubits), normalize=True)
    qml.templates.StronglyEntanglingLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=n_inputs + j)) for j in range(n_hidden)]

qrnn_layer = TorchLayer(
    qrnn_cell, weight_shapes={"weights": (n_layers_rec, n_qubits, 3)}
)
qrnn_layer.batch_execute = False

@qml.qnode(dev_out, interface="torch")
def qnn_readout(inputs, weights):
    for j in range(n_hidden):
        qml.RY(inputs[j], wires=j)
    qml.templates.StronglyEntanglingLayers(weights, wires=range(n_hidden))
    return qml.expval(qml.PauliZ(wires=0))

qnn_out_layer = TorchLayer(
    qnn_readout, weight_shapes={"weights": (n_layers_out, n_hidden, 3)}
)
qnn_out_layer.batch_execute = False

# %%
# ── 3)  QRNN module ──────────────────────────────────────────────────────────
class FullyQuantumRNN(nn.Module):
    def __init__(self):
        super().__init__(); self.qrnn = qrnn_layer; self.qout = qnn_out_layer
    def forward(self, x_seq):                  # (T,B,128)
        B, h = x_seq.shape[1], torch.zeros(batch_size, n_hidden)
        for t in range(x_seq.shape[0]):
            h = torch.stack([self.qrnn(x_seq[t,b]) for b in range(B)])
        return torch.stack([self.qout(h[b]) for b in range(B)]).unsqueeze(1)

# %%
# ── 4)  Perfect efficiency curve ─────────────────────────────────────────────
def true_eff(flow, temp, conc):
    ridge = torch.exp(-0.5*(conc-35)**2)
    peak  = torch.exp(-0.3*(flow-4)**2 - 0.02*(temp-25)**2)
    return 0.95 * ridge * peak

# %%
# ── 5)  Deterministic, noise-free sequences ─────────────────────────────────
def pure_sequences(T, B):
    """
    Build a noise-free physics tensor (T, B, 3) and its matching
    quantum-amplitude tensor (T, B, 128).

    flow  : linear ramp 2→6 m³/s with time
    temp  : mild sinusoid around 25 °C
    conc  : fixed at 35 PSU (ridge)
    """
    flow0 = torch.linspace(2.0, 6.0, B)
    temp0 = torch.linspace(23.0, 27.0, B)
    conc0 = torch.full((B,), 35.0)

    phys = torch.zeros(T, B, 3)
    for t in range(T):
        phys[t, :, 0] = flow0 + 0.1 * t
        phys[t, :, 1] = temp0 + 0.2 * math.sin(0.25 * t)
        phys[t, :, 2] = conc0                               # always 35

    # build amplitude vectors (inner stack → B, outer → T)
    amp = torch.stack([
        torch.stack([encode_to_amplitude(*phys[t, b]) for b in range(B)])
        for t in range(T)
    ])                                                      # (T, B, 128)
    return amp, phys


# ── small preview helper ────────────────────────────────────────────────────
def _preview_last_step(phys_tensor):
    """Show the first 5 samples of the last time-step as a table."""
    last = phys_tensor[-1]                                  # (B,3)
    df = pd.DataFrame(last[:5].numpy(),
                      columns=["flow (m³/s)", "temp (°C)", "conc (PSU)"])
    print("\n▶︎ Preview of input features (last time-step, first 5 samples):")
    print(df.to_string(index=False))
    print()


# ── make_dataset  (returns *three* tensors) ─────────────────────────────────
def make_dataset():
    X_amp, phys = pure_sequences(seq_len, batch_size)

    # perfect efficiency for the last time-step
    last = phys[-1]                                         # (B,3)
    Y    = true_eff(last[:, 0], last[:, 1], last[:, 2]).unsqueeze(1)

    _preview_last_step(phys)                                # optional print

    # return amplitudes, targets, and raw physics
    return X_amp, Y, phys

# %%
# ── Visualise the raw physics data (last time-step) ──────────────────────────
def plot_last_step_features(phys_tensor):
    """
    Scatter: flow (x) vs. temperature (y)  for the last time-step.
    Colour shows sample index, concentration is fixed at 35 PSU.
    """
    last = phys_tensor[-1]                     # shape (B,3)
    flows = last[:, 0].numpy()
    temps = last[:, 1].numpy()

    plt.figure(figsize=(6,4))
    plt.scatter(flows, temps, c=np.arange(len(flows)),
                cmap="viridis", marker="o", edgecolor="k")
    plt.colorbar(label="sample index")
    plt.xlabel("Flow rate  (m³/s)")
    plt.ylabel("Temperature  (°C)")
    plt.title("Feature distribution – last time-step")
    plt.tight_layout()
    plt.show()

# %%
# ── 6)  Train & plot ─────────────────────────────────────────────────────────
def train():
    # ── unpack THREE outputs ──
    X_amp, Y, phys = make_dataset()     # ← phys kept for later plots

    model = FullyQuantumRNN()
    opt   = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    losses  = []

    for epoch in range(1, epochs + 1):
        opt.zero_grad()
        loss = loss_fn(model(X_amp), Y)
        loss.backward()
        opt.step()
        losses.append(loss.item())
        if epoch % plot_every == 0 or epoch == 1:
            print(f"Epoch {epoch:3d} | MSE = {loss.item():.6f}")

    plt.figure(); plt.plot(losses)
    plt.xlabel("Epoch"); plt.ylabel("MSE")
    plt.title("Training (pure quantum states)"); plt.tight_layout(); plt.show()

    # return BOTH the trained model and the physics tensor
    return model, phys

def overlay(model):
    flows = torch.linspace(0,10,120)[:,None]
    temps = torch.full_like(flows,25.); concs = torch.full_like(flows,35.)
    x = torch.stack([encode_to_amplitude(f,t,c)
                     for f,t,c in zip(flows,temps,concs)]).unsqueeze(0)
    with torch.no_grad():
        pred  = model(x).squeeze()
        truth = true_eff(flows.squeeze(),temps.squeeze(),concs.squeeze())
    plt.figure(figsize=(6,4))
    plt.plot(flows, truth, label="Perfect efficiency")
    plt.plot(flows, pred, "--", label="QRNN predicted")
    plt.xlabel("Flow rate (m³/s)"); plt.ylabel("Efficiency")
    plt.title("QRNN vs Perfect Curve (pure inputs)"); plt.legend(); plt.tight_layout(); plt.show()

# %%
print("Training with *pure* quantum inputs …")
t0 = time.perf_counter()

net, phys = train()      # ← receive phys here
overlay(net)             # overlay() only needs the model

print(f"Finished in {time.perf_counter() - t0:.1f}s")
# Out:
# Training with *pure* quantum inputs …
#
# ▶︎ Preview of input features (last time-step, first 5 samples):
#  flow (m³/s)  temp (°C)  conc (PSU)
#     3.100000  23.076332        35.0
#     3.229032  23.205364        35.0
#     3.358065  23.334396        35.0
#     3.487097  23.463428        35.0
#     3.616129  23.592461        35.0
# ---------------------------------------------------------------------------
# WireError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 print("Training with *pure* quantum inputs …")
#       2 t0 = time.perf_counter()
# ----> 4 net, phys = train()      # ← receive phys here
#       5 overlay(net)             # overlay() only needs the model
#       7 print(f"Finished in {time.perf_counter() - t0:.1f}s")
#
# Cell In[12], line 13, in train()
#      11 for epoch in range(1, epochs + 1):
#      12     opt.zero_grad()
# ---> 13     loss = loss_fn(model(X_amp), Y)
#      14     loss.backward()
#      15     opt.step()
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[8], line 8, in FullyQuantumRNN.forward(self, x_seq)
#       6 B, h = x_seq.shape[1], torch.zeros(batch_size, n_hidden)
#       7 for t in range(x_seq.shape[0]):
# ----> 8     h = torch.stack([self.qrnn(x_seq[t,b]) for b in range(B)])
#       9 return torch.stack([self.qout(h[b]) for b in range(B)]).unsqueeze(1)
#
# Cell In[8], line 8, in <listcomp>(.0)
#       6 B, h = x_seq.shape[1], torch.zeros(batch_size, n_hidden)
#       7 for t in range(x_seq.shape[0]):
# ----> 8     h = torch.stack([self.qrnn(x_seq[t,b]) for b in range(B)])
#       9 return torch.stack([self.qout(h[b]) for b in range(B)]).unsqueeze(1)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/qnn/torch.py:404, in TorchLayer.forward(self, inputs)
#     401     inputs = torch.reshape(inputs, (-1, inputs.shape[-1]))
#     403 # calculate the forward pass as usual
# --> 404 results = self._evaluate_qnode(inputs)
#     406 if isinstance(results, tuple):
#     407     if has_batch_dim:
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/qnn/torch.py:430, in TorchLayer._evaluate_qnode(self, x)
#     418 """Evaluates the QNode for a single input datapoint.
#     419
#     420 Args:
#    (...)
#     424     tensor: output datapoint
#     425 """
#     426 kwargs = {
#     427     **{self.input_arg: x},
#     428     **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     429 }
# --> 430 res = self.qnode(**kwargs)
#     432 if isinstance(res, torch.Tensor):
#     433     return res.type(x.dtype)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/qnode.py:1020, in QNode.__call__(self, *args, **kwargs)
#    1018 if qml.capture.enabled():
#    1019     return qml.capture.qnode_call(self, *args, **kwargs)
# -> 1020 return self._impl_call(*args, **kwargs)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/qnode.py:1008, in QNode._impl_call(self, *args, **kwargs)
#    1005 self._update_gradient_fn(shots=override_shots, tape=self._tape)
#    1007 try:
# -> 1008     res = self._execution_component(args, kwargs, override_shots=override_shots)
#    1009 finally:
#    1010     if old_interface == "auto":
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/qnode.py:957, in QNode._execution_component(self, args, kwargs, override_shots)
#     951     warnings.filterwarnings(
#     952         action="ignore",
#     953         message=r".*argument is deprecated and will be removed in version 0.39.*",
#     954         category=qml.PennyLaneDeprecationWarning,
#     955     )
#     956     # pylint: disable=unexpected-keyword-arg
# --> 957     res = qml.execute(
#     958         (self._tape,),
#     959         device=self.device,
#     960         gradient_fn=self.gradient_fn,
#     961         interface=self.interface,
#     962         transform_program=full_transform_program,
#     963         inner_transform=inner_transform_program,
#     964         config=config,
#     965         gradient_kwargs=self.gradient_kwargs,
#     966         override_shots=override_shots,
#     967         **execute_kwargs,
#     968     )
#     969 res = res[0]
#     971 # convert result to the interface in case the qfunc has no parameters
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/execution.py:771, in execute(tapes, device, gradient_fn, interface, transform_program, inner_transform, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp, mcm_config)
#     763 ml_boundary_execute = _get_ml_boundary_execute(
#     764     interface,
#     765     config.grad_on_execution,
#     766     config.use_device_jacobian_product,
#     767     differentiable=max_diff > 1,
#     768 )
#     770 if interface in jpc_interfaces:
# --> 771     results = ml_boundary_execute(tapes, execute_fn, jpc, device=device)
#     772 else:
#     773     results = ml_boundary_execute(
#     774         tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n=1, max_diff=max_diff
#     775     )
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/interfaces/torch.py:236, in execute(tapes, execute_fn, jpc, device)
#     228     parameters.extend(tape.get_parameters())
#     230 kwargs = {
#     231     "tapes": tuple(tapes),
#     232     "execute_fn": execute_fn,
#     233     "jpc": jpc,
#     234 }
# --> 236 return ExecuteTapes.apply(kwargs, *parameters)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/interfaces/torch.py:89, in pytreeify.<locals>.new_apply(*inp)
#      86 def new_apply(*inp):
#      87     # Inputs already flat
#      88     out_struct_holder = []
# ---> 89     flat_out = orig_apply(out_struct_holder, *inp)
#      90     return pytree.tree_unflatten(flat_out, out_struct_holder[0])
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/interfaces/torch.py:93, in pytreeify.<locals>.new_forward(ctx, out_struct_holder, *inp)
#      92 def new_forward(ctx, out_struct_holder, *inp):
# ---> 93     out = orig_fw(ctx, *inp)
#      94     flat_out, out_struct = pytree.tree_flatten(out)
#      95     ctx._out_struct = out_struct
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/interfaces/torch.py:158, in ExecuteTapes.forward(ctx, kwargs, *parameters)
#     155 ctx.tapes = kwargs["tapes"]
#     156 ctx.jpc = kwargs["jpc"]
# --> 158 res = tuple(kwargs["execute_fn"](ctx.tapes))
#     160 # if any input tensor uses the GPU, the output should as well
#     161 ctx.torch_device = None
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/workflow/execution.py:209, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     206 if cache is not None:
#     207     transform_program.add_transform(_cache_transform, cache=cache)
# --> 209 transformed_tapes, transform_post_processing = transform_program(tapes)
#     211 if transformed_tapes:
#     212     results = device.execute(transformed_tapes, execution_config=execution_config)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/transforms/core/transform_program.py:515, in TransformProgram.__call__(self, tapes)
#     513 if self._argnums is not None and self._argnums[i] is not None:
#     514     tape.trainable_params = self._argnums[i][j]
# --> 515 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     516 execution_tapes.extend(new_tapes)
#     518 fns.append(fn)
#
# File ~/.qbraid/environments/pennylane_l1hffv/pyenv/lib/python3.9/site-packages/pennylane/devices/preprocess.py:134, in validate_device_wires(tape, wires, name)
#     132 if wires:
#     133     if extra_wires := set(tape.wires) - set(wires):
# --> 134         raise WireError(
#     135             f"Cannot run circuit(s) on {name} as they contain wires "
#     136             f"not found on the device: {extra_wires}"
#     137         )
#     138     measurements = tape.measurements.copy()
#     139     modified = False
#
# WireError: Cannot run circuit(s) on RemoteDevice as they contain wires not found on the device: {3, 4, 5, 6}

# %%
from matplotlib import pyplot as plt, cm
plot_last_step_features(phys)

# %%
#!/usr/bin/env python
"""
quantum_dataset_preview.py
--------------------------

Create the **pure, noise-free** quantum dataset that the QRNN would train on,
*without* running any training.  
The script

1. builds the classical feature tensor `phys`  (shape = T × B × 3),  
2. converts every triple into a **7-qubit product state** |ψ⟩, stored in
   `X_amp`  (shape = T × B × 128),  
3. prints a neat table of the last time-step’s first 5 samples, and  
4. prints the **ket-notation** for the first 3 samples so you can see the
   exact quantum states.

Adjust `seq_len`, `batch_size`, or the feature formulas as you wish.
"""

# ── Imports ──────────────────────────────────────────────────────────────────
import torch, math, functools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ── Parameters identical to the training script ─────────────────────────────
n_inputs, n_hidden = 3, 4
n_qubits           = n_inputs + n_hidden
state_dim          = 2 ** n_qubits
batch_size         = 32
seq_len            = 12

# ── Classical → quantum encoder (pure, unit-norm) ───────────────────────────
def single_qubit_state(theta: torch.Tensor) -> torch.Tensor:
    """Return cos(θ/2)|0⟩ + sin(θ/2)|1⟩  (real amplitudes)."""
    return torch.stack([torch.cos(theta/2), torch.sin(theta/2)])

def kron_n(states):
    vec = states[0]
    for s in states[1:]:
        vec = torch.kron(vec, s)
    return vec

def encode_to_amplitude(flow: float, temp: float, conc: float) -> torch.Tensor:
    """Map one (flow, temp, conc) triple to a 7-qubit product state vector."""
    theta = torch.tensor([
        flow       * math.pi/10,        #  0–10  ➜  0–π
        (temp-20) * math.pi/20,         # 20–40 ➜  0–π
        (conc-30) * math.pi/20          # 30–40 ➜  0–π
    ])
    data_q   = [single_qubit_state(th) for th in theta]    # 3 qubits
    hidden_q = [torch.tensor([1., 0.])] * n_hidden         # four |0⟩ qubits
    vec      = kron_n(data_q + hidden_q)
    return vec / vec.norm()                                # (128,)

# ── Build deterministic, noise-free sequences ───────────────────────────────
def pure_sequences(T=seq_len, B=batch_size):
    flow0 = torch.linspace(2.0, 6.0, B)
    temp0 = torch.linspace(23.0, 27.0, B)
    conc0 = torch.full((B,), 35.0)

    phys = torch.zeros(T, B, 3)
    for t in range(T):
        phys[t,:,0] = flow0 + 0.1 * t
        phys[t,:,1] = temp0 + 0.2 * math.sin(0.25 * t)
        phys[t,:,2] = conc0                       # fixed ridge at 35 PSU

    X_amp = torch.stack([
        torch.stack([encode_to_amplitude(*phys[t,b]) for b in range(B)])
        for t in range(T)
    ])                                           # (T, B, 128)
    return X_amp, phys

# ── Pretty-print helper for the last time-step ───────────────────────────────
def preview_last_step(phys_tensor):
    last = phys_tensor[-1]                       # (B,3)
    df = pd.DataFrame(last[:5].numpy(),
                      columns=["flow (m³/s)", "temp (°C)", "conc (PSU)"])
    print("\n▶︎ Preview of input features (last time-step, first 5 samples):")
    print(df.to_string(index=False), "\n")

# ── Ket-notation helper for human reading ───────────────────────────────────
def ket_notation(flow, temp, conc, dec=4) -> str:
    """Return the 7-qubit product state as a ket string."""
    θ = [
        math.pi * flow / 10,
        math.pi * (temp - 20) / 20,
        math.pi * (conc - 30) / 20
    ]
    fmt = lambda x: f"{x:+.{dec}f}"
    qubit = lambda th: f"({fmt(math.cos(th/2))}|0⟩ + {fmt(math.sin(th/2))}|1⟩)"
    return qubit(θ[0]) + " ⊗ " + qubit(θ[1]) + " ⊗ " + qubit(θ[2]) + " ⊗ |0000⟩"

# ── Main execution ───────────────────────────────────────────────────────────
if __name__ == "__main__":
    # build data
    X_amp, phys = pure_sequences()

    # 1) table preview
    preview_last_step(phys)

    # 2) show ket notation for first 3 samples
    print("▶︎ Ket notation (first 3 samples of last time-step):\n")
    for idx in range(3):
        f, t, c = phys[-1, idx]
        print(f"sample {idx}:  |ψ⟩ = {ket_notation(float(f), float(t), float(c))}\n")

    # 3) optional scatter of flow vs temperature
    flows = phys[-1,:,0]; temps = phys[-1,:,1]
    plt.figure(figsize=(6,4))
    plt.scatter(flows, temps, c=np.arange(batch_size),
                cmap="viridis", edgecolors="k")
    plt.colorbar(label="sample index")
    plt.xlabel("Flow rate (m³/s)"); plt.ylabel("Temperature (°C)")
    plt.title("Feature distribution – last time-step")
    plt.tight_layout(); plt.show()

    # Data tensors available for export:
    #   • X_amp  – pure quantum amplitude vectors
    #   • phys   – classical features for every time-step
